# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('flights')

# %%
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x='passengers', y='month', data=df)

# %%
sns.relplot(x='passengers', y='month', hue='year', data=df)

# %%
df = sns.load_dataset('tips')
sns.relplot(x='time', y='tip', kind='line', data=df)

# %%
sns.catplot(x="day", y='total_bill', data=df)

# %%
sns.catplot(x="day", y='total_bill', kind='boxen', data=df)

# %%
from scipy import stats

# %%
c = np.random.normal(loc=5, size=100, scale=2)
c
# Out:
# array([6.85660092, 1.80403884, 4.12468174, 4.8240648 , 5.44825213,
#        1.95287739, 3.4049532 , 5.46151741, 3.5936537 , 4.96750458,
#        5.51516263, 4.34279776, 3.23655959, 7.41073296, 4.24169213,
#        0.98562947, 3.74004258, 5.26223751, 3.57242622, 6.80800573,
#        5.83592369, 9.07386475, 4.88922519, 4.59771937, 2.45077071,
#        3.7492918 , 3.08206657, 3.7635295 , 3.47240637, 6.96631182,
#        3.67779184, 2.96187841, 7.51215534, 5.61288029, 6.14206886,
#        2.76034281, 2.83027019, 7.24256749, 5.59568464, 4.4143142 ,
#        5.36970339, 6.89225096, 1.87683969, 4.22906353, 5.09124598,
#        7.07425385, 7.65214803, 5.18750247, 5.71295827, 7.81099413,
#        4.02077426, 2.8868353 , 4.90487122, 7.31729472, 4.43661075,
#        4.5459787 , 4.24899588, 2.25705931, 6.19646023, 6.48999993,
#        6.05925136, 7.19627855, 5.74956769, 5.12831173, 4.08734963,
#        4.26313398, 8.58286192, 4.60822785, 5.67342102, 5.06483955,
#        7.240059  , 6.52444965, 6.16023456, 5.44576271, 5.25708501,
#        7.81290629, 4.77371804, 4.45869174, 2.99677906, 5.44051792,
#        4.94468669, 2.6766596 , 7.89099999, 8.33516736, 5.81304618,
#        7.29872584, 4.95061495, 5.59966916, 5.72806642, 2.38383833,
#        6.15681425, 6.16131928, 4.3305814 , 4.87253102, 6.93555683,
#        4.40273732, 4.76151214, 5.07381099, 8.37709023, 7.12017449])

# %%
sns.distplot(c)

# %% [markdown]
# # Multiple Grid

# %%
a = sns.load_dataset('iris')
b = sns.FacetGrid(a, col='species')
b.map(plt.hist, 'sepal_length')

# %%
a = sns.load_dataset('flights')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %% [markdown]
# # Plot Aesthetic

# %%
sns.set(style='dark')
a = sns.load_dataset('flights')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style='white', color_codes=True)
a = sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill', data=a)

# %%
sns.set(style='white', color_codes=True)
a = sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill', data=a)
sns.despine(offset=10, trim=True)

# %% [markdown]
# # Import Datasets

# %%
crash_df = sns.load_dataset("car_crashes")
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
