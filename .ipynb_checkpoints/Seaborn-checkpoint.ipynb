# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('flights')

# %%
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x='passengers', y='month', data=df)

# %%
sns.relplot(x='passengers', y='month', hue='year', data=df)

# %%
df = sns.load_dataset('tips')
sns.relplot(x='time', y='tip', kind='line', data=df)

# %%
sns.catplot(x="day", y='total_bill', data=df)

# %%
sns.catplot(x="day", y='total_bill', kind='boxen', data=df)

# %%
from scipy import stats

# %%
c = np.random.normal(loc=5, size=100, scale=2)
c
# Out:
# array([ 5.84575219,  5.88934088,  3.92604659,  3.99097914,  5.11151444,
#         6.87532774,  4.01149633,  5.0768873 ,  7.81473543,  2.64920509,
#         4.3766617 ,  3.46941288,  7.34275095,  1.45754655,  3.64042225,
#         7.67232612,  2.05430324,  7.95023943,  4.76933628,  4.85879951,
#         3.27488468,  4.62888706,  4.31123318,  2.63545202,  7.68888205,
#         3.52920361,  4.8325815 ,  4.13410616, 10.44211565,  4.31741152,
#         4.91825616,  2.98912381,  6.81386833,  4.28291309,  7.3699381 ,
#         5.09887597,  2.4330277 ,  9.82529848,  3.47756195,  2.55699161,
#         8.68197008,  3.07930649,  7.03668887,  1.86367681,  7.90638645,
#         5.02577415,  2.89201481,  1.60959474,  3.35762912,  4.97981317,
#         6.61295243,  8.71030556,  6.93813349,  5.09243902,  4.18701823,
#         4.12468049,  6.65781487,  6.23844808,  2.57591892,  5.15908752,
#         6.77755187,  5.72534448,  7.44307427,  2.81147619,  4.02318211,
#         4.6744532 ,  3.89150122,  9.010607  ,  6.02744309,  4.57966014,
#         6.02522811,  3.41687549,  7.5232287 ,  4.40804517,  3.83861325,
#         4.08255486,  7.18569089,  2.10139307,  4.01680063,  2.68755835,
#         2.42447291,  6.31022323,  5.74847163,  3.56653116,  2.3351767 ,
#         3.34284412,  3.67092398,  5.813979  ,  8.70700036,  3.57094908,
#         8.08877763,  1.52639077,  4.19345725,  5.2033969 ,  4.94734856,
#         3.89472167,  5.17643659,  4.8615239 ,  3.8250466 ,  0.51450463])

# %%
sns.distplot(c)

# %% [markdown]
# # Multiple Grid

# %%
a = sns.load_dataset('iris')
b = sns.FacetGrid(a, col='species')
b.map(plt.hist, 'sepal_length')

# %%
a = sns.load_dataset('flights')
b = sns.PairGrid(a)
b.map(plt.scatter)

# %% [markdown]
# # Plot Aesthetic
